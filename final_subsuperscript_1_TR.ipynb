# %%
print("final gen_TR1")
# Out:
# final gen_TR1

# %% [markdown]
# tairens latest code taken from tryin3_TR

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.font_manager import FontProperties
import matplotlib.image as mpimg
import numpy as np
from PIL import Image
import sys
import PIL
import os
from io import BytesIO
# from generated_color_by_contrast import ensure_readable_colors, contrast_ratio

def crop_extra_boundary(image:PIL.Image) -> PIL.Image:
    img_array = np.array(image)
    
    # For transparent PNG, find the alpha channel (if it exists)
    if img_array.shape[2] == 4:  # RGBA
        # Find non-transparent pixels
        non_empty_columns = np.where(img_array[:, :, 3].max(axis=0) > 0)[0]
        non_empty_rows = np.where(img_array[:, :, 3].max(axis=1) > 0)[0]
    else:  # RGB
        # Use inverted approach - find non-white pixels (assuming white background)
        is_not_white = (img_array[:, :, 0] < 255) | (img_array[:, :, 1] < 255) | (img_array[:, :, 2] < 255)
        non_empty_columns = np.where(is_not_white.any(axis=0))[0]
        non_empty_rows = np.where(is_not_white.any(axis=1))[0]
    
    # Crop the image to content only if there are non-empty pixels
    if len(non_empty_rows) > 0 and len(non_empty_columns) > 0:
        cropped_img = img_array[
            min(non_empty_rows):max(non_empty_rows) + 1,
            min(non_empty_columns):max(non_empty_columns) + 1
        ]
        # Convert back to PIL
        final_img = Image.fromarray(cropped_img)
    else:
        final_img = image
    
    return final_img


def generate_text_image(
    main_text="Text",
    super_text=None,
    sub_text=None,
    text_color=(0.0, 0.0, 0.0, 1.0),
    font_size=22,
    left_adjustment=0.02,
    super_sub_position=0.5, # For the superscript, it moves higher; for subscript, it moves lower
    super_sub_size=5, # define the superscript or subscript font size
    dpi=300,
    font_type = 'serif',
    transparent=True
):
    """
    Generate an image with just text (superscript/subscript)
    """
    # Create combined text
    combined_text = main_text
    
    super_sub_position = str(super_sub_position) + "ex"
    # super_sub_size = super_sub_size_map[super_sub_size]
    
    buf = BytesIO()
    #special case for $ adn percent ##################
    # if "$" in main_text or "%" in main_text or "#" in main_text or "&" in main_text or "\\" in main_text:
    #     main_text = main_text.replace("\\", "").replace("$", "\$").replace("%", "\%").replace("#", "\#").replace("&", "\&")

    if "$" in main_text or "%" in main_text or "#" in main_text or "&" in main_text:
        main_text = main_text.replace("$", "\$").replace("%", "\%").replace("#", "\#").replace("&", "\&")
    #############################################################
    if super_text and not sub_text:
        super_or_sub = 0
            
        combined_text = f"{main_text}$^{{\\raisebox{{{super_sub_position}}}{{\\fontsize{{{super_sub_size}}}{{0}}\\selectfont {super_text}}}}}$"
        
        # Add space between the main text and superscript
        # combined_text = f"{main_text}\\hspace{{0.2em}}$^{{\\raisebox{{{super_sub_position}}}{{\\fontsize{{{super_sub_size}}}{{0}}\\selectfont {super_text}}}}}$"
    
    elif sub_text and not super_text:
        super_or_sub = 1
        super_sub_position = "-" + super_sub_position        
        combined_text = f"{main_text}$_{{\\raisebox{{{super_sub_position}}}{{\\fontsize{{{super_sub_size}}}{{0}}\\selectfont  {sub_text}}}}}$"
    
    elif super_text and sub_text:
        super_or_sub = 2
        adjusted_sub_position = "-" + super_sub_position  # for subscript (negative lift)
        combined_text = (
            f"{main_text}"
            f"$^{{\\raisebox{{{super_sub_position}}}{{\\fontsize{{{super_sub_size}}}{{0}}\\selectfont {super_text}}}}}"
            f"_{{\\raisebox{{{adjusted_sub_position}}}{{\\fontsize{{{super_sub_size}}}{{0}}\\selectfont {sub_text}}}}}$"
        )

    else:
        # If neither super_text nor sub_text
        super_or_sub = -1
        combined_text = main_text
        
    
    # Set font
    font_prop = None
    rcParams['text.usetex'] = True
    rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'
    if font_type.lower() in ['serif', 'sans-serif', 'monospace']:
        rcParams['mathtext.fontset'] = 'custom'
        rcParams['mathtext.rm'] = font_type.lower()
    elif os.path.isfile(font_type):
        # Load TTF font
        font_prop = FontProperties(fname=font_type)
    else:
        raise ValueError("font_type must be 'serif', 'sans-serif', 'monospace', or a valid .ttf path")


    # Create figure
    fig_width = len(combined_text) * font_size / 50
    fig_height = font_size / 50 * 1.5
    
    fig = plt.figure(figsize=(fig_width, fig_height), dpi=dpi)
    ax = fig.add_subplot(111)
    ax.set_axis_off()
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
        
    # Add text with slight position adjustment
    text = ax.text(
        0.5 - left_adjustment, 0.5, combined_text,
        ha='center', va='center',
        fontsize=font_size,
        color=text_color,
        fontproperties=font_prop,
        transform=ax.transAxes
    )
    
    # First draw to get the bbox
    fig.canvas.draw()
    bbox = text.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
        
    # Update figure size
    # to avoid cutting the top of superscirpt, increase the bbox.height by 50%
    # then crop it late
    fig.set_size_inches(bbox.width, bbox.height * 1.5 )
    
    # Create a tight layout, which is sensitive to padding
    plt.tight_layout(pad=0)
    
    # Save the image
    plt.savefig(
        buf,
        bbox_inches='tight',
        pad_inches=0,
        transparent=transparent,
        dpi=dpi
    )
    
    # save it for testing
    plt.savefig(
        "./current_test.png",
        bbox_inches='tight',
        pad_inches=0,
        transparent=transparent,
        dpi=dpi
    )
    buf.seek(0)
    gen_image = Image.open(buf)
    
    # crop the white space previously added by increasing the bbox.height
    gen_image = crop_extra_boundary(gen_image)
    
    plt.close()
    
    # Return the dimensions of the generated image
    # img = Image.open(output_path)
    return gen_image.size, gen_image, super_or_sub


def gen_image_random_sample_(wdith_range_bd, height_range_bd, text_size, background_img, pad_all):
    pad_left, pad_top, pad_right, pad_bottom = pad_all
    text_w, text_h = text_size
    sample_width_left = np.random.randint(pad_left, wdith_range_bd + 1)
    sample_height_top = np.random.randint(pad_top, height_range_bd + 1)
    sample_width_right = sample_width_left + text_w
    sample_height_bottom = sample_height_top + text_h
    
    cropped_image = background_img.crop((sample_width_left, sample_height_top, sample_width_right, sample_height_bottom))
    cropped_img_rgb = np.array(cropped_image).mean(axis=(0,1))   
    return cropped_img_rgb, cropped_image, [sample_width_left, sample_height_top, sample_width_right, sample_height_bottom]


def sample_from_bgImage(background_img:Image, text_img_size:list, pad_all:list, generated_text_color:tuple, min_contrast:float =4.5):
    img_w, img_h = background_img.size
    text_w, text_h = text_img_size
    pad_left, pad_top, pad_right, pad_bottom = pad_all

    wdith_range_bd = img_w - text_w - pad_left - pad_right
    height_range_bd = img_h - text_h - pad_top - pad_bottom

    if wdith_range_bd > 0 and height_range_bd > 0:
                
        cropped_img_rgb, cropped_image, sample_indices = gen_image_random_sample_(wdith_range_bd, height_range_bd, [text_w, text_h], background_img, pad_all)
        
        count_contrast = 0
        use_bg = True
        
        while contrast_ratio(generated_text_color, cropped_img_rgb) < min_contrast:
            cropped_img_rgb, cropped_image, sample_indices = gen_image_random_sample_(wdith_range_bd, height_range_bd, [text_w, text_h], background_img, pad_all)
            if count_contrast > 20:
                print("background does not have enough contrast with text")
                print("Generate the background instead")
                use_bg = False
                break
            count_contrast += 1
        
        [sample_width_left, sample_height_top, sample_width_right, sample_height_bottom] = sample_indices
        extend_left = sample_width_left - pad_left
        extend_right = sample_width_right + pad_right
        extend_top = sample_height_top - pad_top
        extend_bottom = sample_height_bottom + pad_bottom
        
        if not use_bg:
            text_width = sample_width_right - sample_width_left
            text_height = sample_height_bottom - sample_height_top
            upd_text_width = text_width + pad_left + pad_right
            upd_text_height = text_height + pad_top + pad_bottom
            generated_text_color, generated_bkground_color, new_ctr = ensure_readable_colors(generated_text_color, cropped_img_rgb, fix_color=1)
            cropped_image = Image.new('RGBA', (text_width, text_height), generated_bkground_color)
            background_img_ext = Image.new('RGBA', (upd_text_width, upd_text_height), generated_bkground_color)
            
        else:    
            background_img_ext = background_img.crop((extend_left, extend_top, extend_right, extend_bottom))
            
        return cropped_image, background_img_ext
                
    else:
        return None, None


def overlay_on_background(
    gen_text_image,
    output_path,
    generated_text_color,
    background_image_path=None,
    gen_bg_color='white',
    pad_all = [0, 0, 0, 0],
):
    """
    Overlay the text image on a background image
    
    Parameters:
    -----------
    text_image_path : str
        Path to the text image
    background_image_path : str
        Path to the background image
    output_path : str
        Path to save the combined image
    position : str or tuple
        'center' or (x, y) coordinates for positioning
    scale_background : bool
        If True, scales the background to match text size
        If False, crops the background to match text size
    """
    try:
        # Open the images
        text_img = gen_text_image #Image.open(text_image_path)        
        # Get dimensions
        text_width, text_height = text_img.size
        
        # Crop background to match text dimensions
        # If background is smaller than text, it will be centered
        pad_left, pad_top, pad_right, pad_bottom = pad_all
        if background_image_path is None:
            # Create a new blank image with text dimensions
            upd_text_width = text_width + pad_left + pad_right
            upd_text_height = text_height + pad_top + pad_bottom
            
            background_img = Image.new('RGBA', (text_width, text_height), gen_bg_color)
            background_img_ext = Image.new('RGBA', (upd_text_width, upd_text_height), gen_bg_color)
            
        else:
            background_img = Image.open(background_image_path)
            background_img, background_img_ext = sample_from_bgImage(background_img, [text_width, text_height], pad_all, generated_text_color)
        
        # Create a new image with RGBA mode to handle transparency
        combined_img = Image.new('RGBA', text_img.size, (0, 0, 0, 0))
        
        # Paste the background first
        combined_img.paste(background_img, (0, 0))
    
        # Overlay the text (with transparency)
        if text_img.mode == 'RGBA':
            combined_img = Image.alpha_composite(combined_img, text_img)
        else:
            # Convert to RGBA if needed
            text_img_rgba = text_img.convert('RGBA')
            combined_img = Image.alpha_composite(combined_img, text_img_rgba)
    
        # Save the combined image
        # combined_img.save(output_path)
        print(f"Combined image saved to {output_path}")
        background_img_ext.paste(combined_img, (pad_left, pad_top))
        background_img_ext.save(output_path)
    
    
    except Exception as e:
        print(f"Error overlaying images: {e}")


def normalize_rgba(rgba):
    return tuple(c / 255 for c in rgba)


def denormalize_rgba(rgba):
    return tuple(255 * c for c in rgba)





##############################################################################
# using The Web Content Accessibility Guidelines (WCAG) define specific contrast requirements:
#
#
#

import random
import numpy as np

def get_luminance(color):
    """Calculate relative luminance of an RGB color"""
    if len(color) > 3:
        color = color[:3]
    r, g, b = [c/255 for c in color]
    
    # Convert to sRGB
    r = r/12.92 if r <= 0.03928 else ((r+0.055)/1.055)**2.4
    g = g/12.92 if g <= 0.03928 else ((g+0.055)/1.055)**2.4
    b = b/12.92 if b <= 0.03928 else ((b+0.055)/1.055)**2.4
    
    return 0.2126 * r + 0.7152 * g + 0.0722 * b


def contrast_ratio(color1, color2):
    """Calculate contrast ratio between two colors"""
    lum1 = get_luminance(color1)
    lum2 = get_luminance(color2)
    
    # Ensure lighter color is first
    if lum1 < lum2:
        lum1, lum2 = lum2, lum1
        
    return (lum1 + 0.05) / (lum2 + 0.05)


def generate_contrasting_colors(fixed_color, min_contrast=4.5):
    """Generate text and background colors with minimum contrast ratio"""
    while True:
        # Generate random background color
        gen_color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
            
        # Check if contrast is sufficient
        new_ctr = contrast_ratio(fixed_color, gen_color)
        if new_ctr >= min_contrast:
            return fixed_color, gen_color, new_ctr


def ensure_readable_colors(text_color_in, bg_color_in, min_contrast=4.5, fix_color=1):
    """
    fix_color: whether to fix color or not
             1: fix the text color 
             2: fix the background color
    Check if text and background colors have enough contrast.
    If not, adjust the text color for better readability.
    """
    if len(text_color_in) > 3:
        text_color = text_color_in[:3]
    else:
        text_color = text_color_in
    
    if len(bg_color_in) > 3:
        bg_color = bg_color_in[:3]
    else:
        bg_color = bg_color_in
    
    cr = contrast_ratio(text_color, bg_color)
    
    if cr >= min_contrast:
        return text_color, bg_color, cr
    
    if fix_color == 1:
        text_color, bg_color, new_ctr = generate_contrasting_colors(text_color)
    else:
        text_color, bg_color, new_ctr = generate_contrasting_colors(bg_color)
        
    if len(text_color) == 3 and len(text_color_in) == 4:
        text_color_list = list(text_color)
        text_color_list.append(text_color_in[-1])
        text_color = tuple(text_color_list)
        
    if len(bg_color) == 3 and len(bg_color_in) == 4:
        bg_color_list = list(bg_color)
        bg_color_list.append(bg_color_in[-1])
        bg_color = tuple(bg_color_list)

    return text_color, bg_color, new_ctr

##############################################################################

# %% [markdown]
# generation function

# %% [markdown]
# create function to create train and test set

# %%
import os 
import random
def create_main_text_files(file_path1 = None, 
                           file_path2 = None , 
                           file_path3=None,
                           percent1=0.5,
                           percent2=0.5,
                           percent3=0.5,
                           num_samples=1000,
                           output_path = None,
                           test = False):
    #take percent1 words from file_path1
    total_percent = percent1 + percent2 + percent3
    if total_percent != 1:
        raise ValueError("Sum of percentages must be equal to 1")
    os.makedirs(output_path, exist_ok=True)
    words1 = []
    words2 = []
    words3 = []
    
    
    #store words
    if file_path1:
        with open(file_path1, 'r', encoding='utf-8') as f:
            words1 = [line.strip() for line in f if line.strip()]
    if file_path2:
        with open(file_path2, 'r', encoding='utf-8') as f:
            words2 = [line.strip() for line in f if line.strip()]
    if file_path3:
        with open(file_path3, 'r', encoding='utf-8') as f:
            words3 = [line.strip() for line in f if line.strip()]
    # Calculate number of samples per file
    num_words1 = int(num_samples * percent1)
    num_words2 = int(num_samples * percent2)
    num_words3 = int(num_samples * percent3)
    # Make sure we don't sample more than available
    num_words1 = min(num_words1, len(words1))
    num_words2 = min(num_words2, len(words2))
    num_words3 = min(num_words3, len(words3))
    
    # Sample words from each list
    if words1 and  num_words1 > 0:
        sampled_words1 = random.sample(words1, num_words1)
    if words2 and num_words2 > 0:
        sampled_words2 = random.sample(words2, num_words2)
    if words3 and num_words3 > 0:
        sampled_words3 = random.sample(words3, num_words3)
    #write to output file
    num_sample_1 = len(sampled_words1) if num_words1 > 0 else 0
    num_sample_2 = len(sampled_words2) if num_words2 > 0 else 0
    num_sample_3 = len(sampled_words3) if num_words3 > 0 else 0
    
    if num_sample_1 + num_sample_2 + num_sample_3 < num_samples:
        #choose the remaining words from the first two files chosen randomly
        remaining_words = num_samples - (num_sample_1 + num_sample_2 + num_sample_3)
        words_to_choose_from =  words1 + words2
        words_already_chosen = sampled_words1 + sampled_words2
        words_to_choose_from = [word for word in words_to_choose_from if word not in words_already_chosen]
        if len(words_to_choose_from) < remaining_words:
            raise ValueError("Not enough words to sample from the first two files")
        sampled_remaining_words = random.sample(words_to_choose_from, remaining_words)
        sampled_words1 += sampled_remaining_words
        num_sample_1 = len(sampled_words1)
        num_sample_2 = len(sampled_words2)
         
            
    
    output_file = 'test_main_text.txt' if test else 'train_main_text.txt'
    with open(os.path.join(output_path, output_file), 'w', encoding='utf-8') as f:
        if num_words1 > 0:
            for word in sampled_words1:
                f.write(word + '\n')
        if num_words2 > 0:
            for word in sampled_words2:
                f.write(word + '\n')
        if num_words3 > 0 and test == False:
            for word in sampled_words3:
                f.write(word + '\n')
    
    if test == False:
        print(f"train_main_text.txt created with {num_sample_1 + num_sample_2 + num_sample_3} words saved to {output_path}")
        print(f"{num_sample_1} words from {file_path1}")
        print(f"{num_sample_2} words from {file_path2}")
        print(f"{num_sample_3} words from {file_path3}")
    
    else:
        print(f"test_main_text.txt created with {num_words1 + num_words2} words saved to {output_path}")
        print(f"{num_sample_1} words from {file_path1}")
        print(f"{num_sample_2} words from {file_path2}")

# %% [markdown]
# create train dataset

# %%
create_main_text_files(file_path1 = "../words1/output2/train_data_words_TR/unique_texts.txt", 
                           file_path2 = "../words1/output2/train_data_words_TR/unique_nums.txt", 
                           file_path3="../words1/output_json_1_TR/output_unique_individual_words.txt",
                           percent1=0.46,
                           percent2=0.27,
                           percent3=0.27,
                           num_samples=10000,
                           output_path = "./data_1/train_1_TR",
                           test = False)
# Out:
# train_main_text.txt created with 10000 words saved to ./data_1/train_1_TR
# 6945 words from ../words1/output2/train_data_words_TR/unique_texts.txt
# 2700 words from ../words1/output2/train_data_words_TR/unique_nums.txt
# 355 words from ../words1/output_json_1_TR/output_unique_individual_words.txt

# %% [markdown]
# create test dataset

# %%
create_main_text_files(file_path1 = "../words1/output2/train_data_words_TR/unique_texts.txt", 
                           file_path2 = "../words1/output2/train_data_words_TR/unique_nums.txt", 
                           file_path3="../words1/output_json_1_TR/output_unique_individual_words.txt",
                           percent1=0.60,
                           percent2=0.40,
                           percent3=0.0,
                           num_samples=1200,
                           output_path = "./data_1/test_1_TR",
                           test = False)
# Out:
# train_main_text.txt created with 1200 words saved to ./data_1/test_1_TR
# 720 words from ../words1/output2/train_data_words_TR/unique_texts.txt
# 480 words from ../words1/output2/train_data_words_TR/unique_nums.txt
# 0 words from ../words1/output_json_1_TR/output_unique_individual_words.txt

# %% [markdown]
# guasain function

# %%
import numpy as np
from scipy.stats import truncnorm

def sample_truncnorm_with_tail_and_baseline(min_val, max_val, mean, std,
                                             tail_smooth='both',
                                             suppression_strength=3.0,
                                             baseline_weight=0.2,
                                             size=1000, grid_points=1000, seed=None,
                                             return_pdf=False):

    if seed is not None:
        np.random.seed(seed)

    if tail_smooth not in ['left', 'right', 'both', None]:
        raise ValueError("tail_smooth must be 'left', 'right', 'both', or None")

    # Step 1: Grid over support
    x = np.linspace(min_val, max_val, grid_points)

    # Step 2: Truncated normal PDF
    a = (min_val - mean) / std
    b = (max_val - mean) / std
    gauss_pdf = truncnorm.pdf(x, a=a, b=b, loc=mean, scale=std)

    # Step 3: Exponential tail suppression
    if tail_smooth in ['left', 'both']:
        mask_left = x < mean
        decay_left = np.exp(-suppression_strength * (mean - x[mask_left]))
        gauss_pdf[mask_left] *= decay_left

    if tail_smooth in ['right', 'both']:
        mask_right = x > mean
        decay_right = np.exp(-suppression_strength * (x[mask_right] - mean))
        gauss_pdf[mask_right] *= decay_right

    # Step 4: Uniform baseline PDF
    baseline_pdf = np.ones_like(x) / (max_val - min_val)

    # Step 5: Mix PDFs
    mixed_pdf = (1 - baseline_weight) * gauss_pdf + baseline_weight * baseline_pdf

    # Step 6: Normalize
    mixed_pdf /= mixed_pdf.sum()

    # Step 7: Sample
    samples = np.random.choice(x, size=size, p=mixed_pdf)

    if return_pdf:
        return samples, x, mixed_pdf
    return samples
###########################################################################
import matplotlib.pyplot as plt

def plot_sample_histogram(samples, x=None, pdf=None,
                          bins=50, title="Sampled Value Distribution"):
    plt.figure(figsize=(10, 6))

    # Plot histogram
    counts, bins, _ = plt.hist(samples, bins=bins, density=True,
                               alpha=0.7, color='#4a90e2',
                               edgecolor='white', linewidth=1.2,
                               label="Sample Histogram")

    # Overlay PDF if provided
    if x is not None and pdf is not None:
        plt.plot(x, pdf, color='crimson', lw=2, label='Theoretical PDF')

    # Titles and labels
    plt.title(title, fontsize=16, weight='bold')
    plt.xlabel("Value", fontsize=14)
    plt.ylabel("Density", fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)

    # Grid and legend
    plt.grid(alpha=0.3)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# sample digits

# %%
def plot_distribution(sampler_func, label, num_samples=10000):
    samples = [sampler_func() for _ in range(num_samples)]
    freq = {c: samples.count(c)/num_samples for c in set(samples)}
    
    sorted_freq = dict(sorted(freq.items()))
    
    plt.figure(figsize=(10, 4))
    bars = plt.bar(sorted_freq.keys(), sorted_freq.values())
    plt.title(f"{label} Frequency Distribution")
    plt.xlabel(label)
    plt.ylabel("Frequency")
    plt.grid(True, linestyle='--', axis='y', alpha=0.5)

    # Add percentage labels on top of bars
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.005,
                 f'{height*100:.1f}%', ha='center', va='bottom', fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
def sample_digit():
    digits = list('123456789')
    n = len(digits)
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=0.0,  # peak at '1'
        std=3.0,
        tail_smooth='right',
        baseline_weight=0.1,
        suppression_strength=1.5,
        size=1,
        return_pdf = False
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    return digits[idx]

# %%
plot_distribution(sample_digit, "Digit", num_samples=10000)

# %%
def sample_lower():
    letters = list('abcdefghijklmnopqrstuvwxyz')
    n = len(letters)
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=0.0,  # peak at 'a'
        std=5,
        tail_smooth='right',
        baseline_weight=0.1,
        suppression_strength=1.5,
        size=1
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    return letters[idx]

# %%
plot_distribution(sample_lower, "Lowercase Letter", num_samples=10000)

# %%
def sample_upper():
    letters = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')
    n = len(letters)
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=0.0,  # peak at 'A'
        std=18.0,
        tail_smooth='right',
        baseline_weight=0.1,
        suppression_strength=1.5,
        size=1
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    return letters[idx]

# %%
plot_distribution(sample_upper, "uppercase Letter", num_samples=10000)

# %%
def sample_length():
    lengths = [1, 2, 3, 4, 5, 6]
    n = len(lengths)
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0, max_val=n-1, mean=0.0, std=2.0,
        tail_smooth='right', baseline_weight=0.1, size=1,
        suppression_strength=1.5,
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    return lengths[idx]

# %%
sample_time = 1000
from collections import defaultdict
import time
num_count = defaultdict(int)
for i in range(sample_time):
    gen_l = sample_length()
    # time.sleep(0.1)
    # print(" sample length is: ", gen_l)
    num_count[gen_l] += 1

print(num_count)
# Out:
# defaultdict(<class 'int'>, {2: 310, 5: 63, 1: 422, 4: 75, 6: 36, 3: 94})

# %%
plot_distribution(sample_length, "sample Length", num_samples=10000)

# %% [markdown]
# create superscript text

# %% [markdown]
# try 4 (best one) (superscript)

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy.stats import truncnorm
from collections import Counter

np.random.seed(42)
random.seed(42)

digits = list('123456789')
lower_letters = list('abcdefghijklmnopqrstuvwxyz')
upper_letters = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')


def generate_unique_sorted_content(L, sampler_func):
    seen = set()
    attempts = 0
    while len(seen) < L and attempts < 100:
        ch = sampler_func()
        seen.add(ch)
        attempts += 1

    chars = sorted(seen)
    if len(chars) == 0:
        return ''
    return ','.join(chars[:L])



def generate_superscripts_fixed(num_samples):
    total = num_samples

    # Calculate exact number per type
    num_bracket = round(total * 0.45)
    num_digit   = round(total * 0.30)
    num_lower   = round(total * 0.20)
    num_upper   = total - (num_bracket + num_digit + num_lower)

    print(f"\n[INFO] Generating {total} superscripts:")
    print(f"  Digits:   {num_digit}")
    print(f"  Lower:    {num_lower}")
    print(f"  Upper:    {num_upper}")
    print(f"  Brackets: {num_bracket}")

    # Bracket style breakdown
    bracket_round = round(num_bracket * 0.8)
    bracket_square = max(1, round(num_bracket * 0.1))
    bracket_curly = max(1, num_bracket - bracket_round - bracket_square)

    print(f"\n[INFO] Bracket styles:")
    print(f"  → ():     {bracket_round}")
    print(f"  → []:     {bracket_square}")
    print(f"  → {{}}:    {bracket_curly}")

    # Generate bracket types
    all_brackets = (
        ['Round'] * bracket_round +
        ['Square'] * bracket_square +
        ['Curly'] * bracket_curly
    )
    random.shuffle(all_brackets)

    # Number of each content type among brackets
    bracket_digits = int(num_bracket * 0.5)
    bracket_lower = int(num_bracket * 0.45)
    bracket_upper = num_bracket - bracket_digits - bracket_lower

    print("\n[INFO] Bracket inner content distribution:")
    print(f"  → Digit-only:    {bracket_digits}")
    print(f"  → Lower-only:    {bracket_lower}")
    print(f"  → Upper-only:    {bracket_upper}")

    # Build lists of content samplers
    bracket_content_samplers = (
        [('digit', sample_digit)] * bracket_digits +
        [('lower', sample_lower)] * bracket_lower +
        [('upper', sample_upper)] * bracket_upper
    )

    random.shuffle(bracket_content_samplers)

    # build bracketed strings
    i = 0
    results = []

    for bt in all_brackets:
        if i >= len(bracket_content_samplers):
            break
        content_type, sampler = bracket_content_samplers[i]
        L = sample_length()
        inner = generate_unique_sorted_content(L, sampler)

        if bt == 'Round':
            results.append(('()', f'({inner})'))
        elif bt == 'Square':
            results.append(('[]', f'[{inner}]'))
        else:
            inner = "\{" + inner + "\}"
            results.append(('{}', f'{inner}'))

        i += 1

    # Generate non-bracket strings
    for _ in range(num_digit):
        L = sample_length()
        inner = generate_unique_sorted_content(L, sample_digit)
        results.append(('Digit', inner))

    for _ in range(num_lower):
        L = sample_length()
        inner = generate_unique_sorted_content(L, sample_lower)
        results.append(('Lower', inner))

    for _ in range(num_upper):
        L = sample_length()
        inner = generate_unique_sorted_content(L, sample_upper)
        results.append(('Upper', inner))

    # Shuffle final output
    random.shuffle(results)

    # Count stats
    stats = {
        'Digit': 0,
        'Lower': 0,
        'Upper': 0,
        'Round': 0,
        'Square': 0,
        'Curly': 0
    }

    for typ, val in results:
        if typ == '()':
            stats['Round'] += 1
        elif typ == '[]':
            stats['Square'] += 1
        elif typ == '{}':
            stats['Curly'] += 1
        elif typ == 'Digit':
            stats['Digit'] += 1
        elif typ == 'Lower':
            stats['Lower'] += 1
        elif typ == 'Upper':
            stats['Upper'] += 1

    print("\n[INFO] Final Distribution Summary:")
    print(f"Digits:     {stats['Digit']}")
    print(f"Lower:      {stats['Lower']}")
    print(f"Upper:      {stats['Upper']}")
    print(f"Brackets:   {stats['Round'] + stats['Square'] + stats['Curly']}")
    print(f"  → ():     {stats['Round']}")
    print(f"  → []:     {stats['Square']}")
    print(f"  → {{}}:     {stats['Curly']}")

    # Plotting
    categories = ['Digits', 'Lower', 'Upper', '()', '[]', '{}']
    counts = [
        stats['Digit'],
        stats['Lower'],
        stats['Upper'],
        stats['Round'],
        stats['Square'],
        stats['Curly']
    ]

    plt.figure(figsize=(10, 5))
    bars = plt.bar(categories, counts, color=['skyblue', 'lightgreen', 'salmon', 'gold', 'violet', 'cyan'])
    plt.title("Superscript Type Distribution")
    plt.ylabel("Count")
    plt.grid(True, linestyle='--', alpha=0.6)

    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.3,
                 str(int(height)), ha='center', va='bottom', fontsize=9)

    plt.tight_layout()
    plt.show()

    # Return just the string values
    return [val for _, val in results]



if __name__ == '__main__':
    superscripts = generate_superscripts_fixed(1000)

    print("\nFirst 10 generated superscripts:")
    for idx, s in enumerate(superscripts[:10], 1):
        print(f"{idx}: {s}")
# Out:
# [INFO] Generating 1000 superscripts:
#   Digits:   300
#   Lower:    200
#   Upper:    50
#   Brackets: 450
#
# [INFO] Bracket styles:
#   → ():     360
#   → []:     45
#   → {}:    45
#
# [INFO] Bracket inner content distribution:
#   → Digit-only:    225
#   → Lower-only:    202
#   → Upper-only:    23
# [INFO] Final Distribution Summary:
# Digits:     300
# Lower:      200
# Upper:      50
# Brackets:   450
#   → ():     360
#   → []:     45
#   → {}:     45
# First 10 generated superscripts:
# 1: O
# 2: (8)
# 3: C
# 4: (2)
# 5: b
# 6: (I)
# 7: L
# 8: [1]
# 9: 1
# 10: [a,b,c,k,m,t]

# %% [markdown]
# Sub script

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy.stats import truncnorm
from collections import Counter

np.random.seed(42)
random.seed(42)

digits = list('123456789')
lower_letters = list('abcdefghijklmnopqrstuvwxyz')
upper_letters = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')


def generate_unique_sorted_content(L, sampler_func):
    seen = set()
    attempts = 0
    while len(seen) < L and attempts < 100:
        ch = sampler_func()
        seen.add(ch)
        attempts += 1

    chars = sorted(seen)
    if len(chars) == 0:
        return ''
    return ','.join(chars[:L])



def generate_subscript_fixed(num_samples):
    total = num_samples

    # Calculate exact number per type
    # num_bracket = round(total * 0.45)
    num_digit   = round(total * 0.50)
    num_lower   = round(total * 0.30)
    num_upper   = total - (num_digit + num_lower)

    print(f"\n[INFO] Generating {total} superscripts:")
    print(f"  Digits:   {num_digit}")
    print(f"  Lower:    {num_lower}")
    print(f"  Upper:    {num_upper}")
    # print(f"  Brackets: {num_bracket}")
    
    results= []

    # Generate non-bracket strings
    for _ in range(num_digit):
        L = sample_length()
        inner = generate_unique_sorted_content(L, sample_digit)
        results.append(('Digit', inner))

    for _ in range(num_lower):
        L = sample_length()
        inner = generate_unique_sorted_content(L, sample_lower)
        results.append(('Lower', inner))

    for _ in range(num_upper):
        L = sample_length()
        inner = generate_unique_sorted_content(L, sample_upper)
        results.append(('Upper', inner))

    # Shuffle final output
    random.shuffle(results)

    # Count stats
    stats = {
        'Digit': 0,
        'Lower': 0,
        'Upper': 0,
    }

    for typ, val in results:
        if typ == 'Digit':
            stats['Digit'] += 1
        elif typ == 'Lower':
            stats['Lower'] += 1
        elif typ == 'Upper':
            stats['Upper'] += 1

    print("\n[INFO] Final Distribution Summary:")
    print(f"Digits:     {stats['Digit']}")
    print(f"Lower:      {stats['Lower']}")
    print(f"Upper:      {stats['Upper']}")

    # Plotting
    categories = ['Digits', 'Lower', 'Upper']
    counts = [
        stats['Digit'],
        stats['Lower'],
        stats['Upper']
    ]

    plt.figure(figsize=(10, 5))
    bars = plt.bar(categories, counts, color=['skyblue', 'lightgreen', 'salmon'])
    plt.title("Superscript Type Distribution")
    plt.ylabel("Count")
    plt.grid(True, linestyle='--', alpha=0.6)

    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.3,
                 str(int(height)), ha='center', va='bottom', fontsize=9)

    plt.tight_layout()
    plt.show()

    # Return just the string values
    return [val for _, val in results]



subscripts = generate_subscript_fixed(100)

print("\nFirst 10 generated superscripts:")
for idx, s in enumerate(subscripts[:10], 1):
    print(f"{idx}: {s}")
# Out:
# [INFO] Generating 100 superscripts:
#   Digits:   50
#   Lower:    30
#   Upper:    20
#
# [INFO] Final Distribution Summary:
# Digits:     50
# Lower:      30
# Upper:      20
# First 10 generated superscripts:
# 1: 3
# 2: 2
# 3: A,P,U
# 4: 2
# 5: a,b,d,w
# 6: a,h,o,u
# 7: 1,2
# 8: q
# 9: 1,2,5,6,9
# 10: a

# %% [markdown]
# function for random colors and fonts

# %%
# def generate_custom_color_category(tail_smooth='left', suppression_strength=1.0,
#                                          baseline_weight=0.05, seed=None):
#     color_categories = {
#         0: ('dark_blue',  {'r': (0, 30),   'g': (0, 30),   'b': (80, 150)}),
#         1: ('black',      {'r': (0, 30),   'g': (0, 30),   'b': (0, 30)})
#     }

#     category_ids = list(color_categories.keys())
#     num_categories = len(category_ids)

#     mean = 1
#     std = 1

#     index_sample = sample_truncnorm_with_tail_and_baseline(
#         min_val=0,
#         max_val=num_categories - 1,
#         mean=mean,
#         std=std,
#         tail_smooth=tail_smooth,
#         suppression_strength=suppression_strength,
#         baseline_weight=baseline_weight,
#         size=1,
#         seed=seed
#     )[0]

#     selected_index = int(round(index_sample))
#     selected_index = max(min(selected_index, num_categories - 1), 0)

#     cat_key = category_ids[selected_index]
#     cat_name, rgb_ranges = color_categories[cat_key]

#     r = int(random.randint(*rgb_ranges['r']))
#     g = int(random.randint(*rgb_ranges['g']))
#     b = int(random.randint(*rgb_ranges['b']))

#     return cat_name, '#{:02x}{:02x}{:02x}{:02x}'.format(r, g, b, 255)
# ####################################################################
# def generate_custom_color_category_2(tail_smooth='left', suppression_strength=1.0,
#                                    baseline_weight=0.05, seed=None):
#     color_categories = {
#         0: ('dark_blue',  {'r': (0, 30),   'g': (0, 30),   'b': (80, 150)}),
#         1: ('black',      {'r': (0, 30),   'g': (0, 30),   'b': (0, 30)}),
#     }

#     category_ids = list(color_categories.keys())
#     num_categories = len(category_ids)

#     mean = 1
#     std = 1

#     index_sample = sample_truncnorm_with_tail_and_baseline(
#         min_val=0,
#         max_val=num_categories - 1,
#         mean=mean,
#         std=std,
#         tail_smooth=tail_smooth,
#         suppression_strength=suppression_strength,
#         baseline_weight=baseline_weight,
#         size=1,
#         seed=seed
#     )[0]

#     selected_index = int(round(index_sample))
#     selected_index = max(min(selected_index, num_categories - 1), 0)

#     cat_key = category_ids[selected_index]
#     cat_name, rgb_ranges = color_categories[cat_key]

#     r = random.randint(*rgb_ranges['r'])
#     g = random.randint(*rgb_ranges['g'])
#     b = random.randint(*rgb_ranges['b'])
#     a = 255  # Full opacity

#     return cat_name, (r, g, b, a)  # Returning tuple (R, G, B, A)


# def sample_font_color():
#     color_categories = {
#         0: ('black',      {'r': (0, 30),   'g': (0, 30),   'b': (0, 30)}),
#         1: ('dark_blue',  {'r': (0, 30),   'g': (0, 30),   'b': (80, 150)}),
#         2: ('dark_gray', {'r': (50, 100),   'g': (50, 100),   'b': (50, 100)}),
#         3: ('dark_green', {'r': (0, 30),   'g': (60, 100),   'b': (0, 30)}),
#         4: ('red', {'r': (200, 255),   'g': (0, 40),   'b': (0, 40)}),
#         5: ('blue', {'r': (0, 100),   'g': (0, 100),   'b': (180, 255)}),
#         6: ('purple', {'r': (100, 200),   'g': (0, 120),   'b': (120, 225)}),
#         7: ('yellow', {'r': (200, 255),   'g': (180, 255),   'b': (0, 100)}),
#     }
    
#     category_ids = list(color_categories.keys())
#     num_categories = len(category_ids)

#     mean = 0
#     std = 3

#     index_sample = sample_truncnorm_with_tail_and_baseline(
#         min_val=0,
#         max_val=num_categories - 1,
#         mean=mean,  # peak at 'black'
#         std=std,
#         tail_smooth='right',
#         baseline_weight=0.1,
#         suppression_strength=1.5,
#         size=1
#     )[0]

#     selected_index = int(round(index_sample))
#     selected_index = max(min(selected_index, num_categories - 1), 0)

#     cat_key = category_ids[selected_index]
#     cat_name, rgb_ranges = color_categories[cat_key]

#     r = random.randint(*rgb_ranges['r'])
#     g = random.randint(*rgb_ranges['g'])
#     b = random.randint(*rgb_ranges['b'])
#     a = 255  # Full opacity

#     return cat_name, (r, g, b, a)  # Returning tuple (R, G, B, A)


# #####################################################################
# def plot_color_category_distribution(tail_smooth='left', suppression_strength=0.8, baseline_weight=0.1, seed=42):
#     color_categories = {
#         0: 'dark_blue',
#         1: 'black'
#     }

#     min_val = 0
#     max_val = len(color_categories) - 1
#     mean = 1
#     std = 1

#     samples, x, pdf = sample_truncnorm_with_tail_and_baseline(
#         min_val=min_val,
#         max_val=max_val,
#         mean=mean,
#         std=std,
#         tail_smooth=tail_smooth,
#         suppression_strength=suppression_strength,
#         baseline_weight=baseline_weight,
#         size=100000,
#         return_pdf=True,
#         seed=seed
#     )

#     bin_edges = np.arange(min_val - 0.5, max_val + 1.5, 1)
#     plt.figure(figsize=(10, 8))
#     plt.hist(samples, bins=bin_edges, density=True, alpha=0.6, color='skyblue', label='Sampled Category Distribution')
#     # plt.plot(x, pdf, 'r-', lw=2, label='Sampling PDF')
#     plt.xticks(list(color_categories.keys()), [color_categories[i] for i in color_categories])
#     plt.xlabel("Color Categories")
#     plt.ylabel("Probability Density")
#     plt.title("Truncated Normal Sampling over Color Categories")
#     plt.legend()
#     plt.grid(True)
#     plt.tight_layout()
#     plt.show()

# %% [markdown]
# Add new sample_font_color and plot_color_category_distribution_upd

# %%
def sample_font_color():
    color_categories = {
        0: ('black',      {'r': (0, 30),   'g': (0, 30),   'b': (0, 30)}),
        1: ('dark_blue',  {'r': (0, 30),   'g': (0, 30),   'b': (80, 150)}),
        2: ('dark_gray', {'r': (50, 100),   'g': (50, 100),   'b': (50, 100)}),
        3: ('dark_green', {'r': (0, 30),   'g': (60, 100),   'b': (0, 30)}),
        4: ('red', {'r': (200, 255),   'g': (0, 40),   'b': (0, 40)}),
        5: ('blue', {'r': (0, 100),   'g': (0, 100),   'b': (180, 255)}),
        6: ('purple', {'r': (100, 200),   'g': (0, 120),   'b': (120, 225)}),
        7: ('yellow', {'r': (200, 255),   'g': (180, 255),   'b': (0, 100)}),
    }
    
    category_ids = list(color_categories.keys())
    num_categories = len(category_ids)

    mean = 0
    std = 2

    index_sample = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=num_categories - 1,
        mean=mean,  # peak at 'black'
        std=std,
        tail_smooth='right',
        baseline_weight=0.1,
        suppression_strength=1.0,
        size=1
    )[0]

    selected_index = int(round(index_sample))
    selected_index = max(min(selected_index, num_categories - 1), 0)

    cat_key = category_ids[selected_index]
    cat_name, rgb_ranges = color_categories[cat_key]

    r = random.randint(*rgb_ranges['r'])
    g = random.randint(*rgb_ranges['g'])
    b = random.randint(*rgb_ranges['b'])
    a = 255  # Full opacity

    return cat_name, (r, g, b, a)  # Returning tuple (R, G, B, A)

# %%
import matplotlib.pyplot as plt
from collections import Counter

def plot_color_category_distribution(sampler_func, categories, num_samples=1000):
    """
    Plots a horizontal bar chart of color category frequencies sampled from `sampler_func`.

    Parameters:
    - sampler_func: A function returning (category_name, (r, g, b, a))
    - categories: List or dict of categories (e.g., {id: (name, ...)} or [name, ...])
    - num_samples: How many samples to draw
    """
    # Extract category names
    # Get category names
    if isinstance(categories, dict):
        category_names = [categories[i][0] for i in sorted(categories.keys())]
    else:
        category_names = list(categories)

    # Sample the function
    sampled_names = [sampler_func()[0] for _ in range(num_samples)]
    counts = Counter(sampled_names)
    frequencies = [counts.get(name, 0) for name in category_names]

    # Plot
    plt.figure(figsize=(10, 5))
    bars = plt.bar(category_names, frequencies, color='cornflowerblue', edgecolor='black')

    # Add frequency labels on top of each bar
    for bar, freq in zip(bars, frequencies):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 5, str(freq),
                 ha='center', va='bottom', fontsize=9)

    plt.title(f"Color Category Distribution over {num_samples} Samples")
    plt.xlabel("Color Category")
    plt.ylabel("Frequency")
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

# %%
color_categories = {
    0: ('black',      {'r': (0, 30),   'g': (0, 30),   'b': (0, 30)}),
    1: ('dark_blue',  {'r': (0, 30),   'g': (0, 30),   'b': (80, 150)}),
    2: ('dark_gray', {'r': (50, 100),   'g': (50, 100),   'b': (50, 100)}),
    3: ('dark_green', {'r': (0, 30),   'g': (60, 100),   'b': (0, 30)}),
    4: ('red', {'r': (200, 255),   'g': (0, 40),   'b': (0, 40)}),
    5: ('blue', {'r': (0, 100),   'g': (0, 100),   'b': (180, 255)}),
    6: ('purple', {'r': (100, 200),   'g': (0, 120),   'b': (120, 225)}),
    7: ('yellow', {'r': (200, 255),   'g': (180, 255),   'b': (0, 100)}),
}
    

plot_color_category_distribution(sample_font_color, color_categories, num_samples=1000)

# %% [markdown]
# function for font size

# %%
def sample_font_size():
    digits = list(range(2, 21))
    n = len(digits)
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=4.5,  # peak at '1'
        std=2.0,
        tail_smooth='both',
        baseline_weight=0.2,
        suppression_strength=0.5,
        size=1,
        return_pdf = False
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    return digits[idx]

# %%
plot_distribution(sample_font_size, "Font_size", num_samples=1000)

# %% [markdown]
# for background color

# %%
def sample_background_color():
    color_categories = {
        0: ("white",        {'r': (235, 255),'g': (235, 255),'b': (235, 255)}),
        1: ("light_gray", {'r': (210, 240), 'g': (210, 240), 'b': (210, 240)}),
        2: ("light_blue", {'r': (180, 205), 'g': (200, 230), 'b': (230, 255)}),
        3: ("light_yellow", {'r': (230, 255), 'g': (230, 255), 'b': (170, 2000)}),
        4: ("light_red", {'r': (220, 255), 'g': (120, 150), 'b': (120, 150)}),
    }
    
    category_ids = list(color_categories.keys())
    num_categories = len(category_ids)

    mean = 0
    std = 1
    index_sample = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=num_categories - 1,
        mean=mean,  # peak at 'black'
        std=std,
        tail_smooth='right',
        baseline_weight=0.1,
        suppression_strength=1.9,
        size=1
    )[0]

    selected_index = int(round(index_sample))
    selected_index = max(min(selected_index, num_categories - 1), 0)

    cat_key = category_ids[selected_index]
    cat_name, rgb_ranges = color_categories[cat_key]

    r = random.randint(*rgb_ranges['r'])
    g = random.randint(*rgb_ranges['g'])
    b = random.randint(*rgb_ranges['b'])
    a = 255  # Full opacity

    return cat_name, (r, g, b, a)  # Returning tuple (R, G, B, A)

# %%
color_categories = {
    0: ("white",        {'r': (240, 255),'g': (240, 255),'b': (240, 255)}),
    1: ("light_gray", {'r': (210, 240), 'g': (210, 240), 'b': (210, 240)}),
    2: ("light_blue", {'r': (180, 205), 'g': (200, 230), 'b': (230, 255)}),
    3: ("light_yellow", {'r': (230, 255), 'g': (230, 255), 'b': (170, 2000)}),
    4: ("light_red", {'r': (220, 255), 'g': (120, 150), 'b': (120, 150)}),
}
plot_color_category_distribution(sample_background_color, color_categories, num_samples=1000)

# %% [markdown]
# Add sample function for super_sub_position

# %%
def sample_super_sub_position_v1():
    fixed_ratios = [0.5, 0.66, 0.75, 1]
    fixed_ratios = list(range(len(fixed_ratios)))
    n = len(fixed_ratios)
    
    add_varies = random.randint(-5, 5) / 100
    
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=1,  # peak at 'a'
        std=5,
        tail_smooth='both',
        baseline_weight=0.4,
        suppression_strength=0,
        size=1
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    varied_value = fixed_ratios[idx] + add_varies
    if varied_value > 1:
        varied_value = 1
    return fixed_ratios[idx]

def sample_super_sub_position():
    fixed_ratios = [0.5, 0.66, 0.75, 0.85]
    n = len(fixed_ratios)
    
    add_varies = random.randint(-5, 5) / 100
    print("add_varies: ", add_varies)
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=1,  # peak at 'a'
        std=5,
        tail_smooth='both',
        baseline_weight=0.4,
        suppression_strength=0,
        size=1
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    varied_value = fixed_ratios[idx] + add_varies
    if varied_value > 1:
        varied_value = 1
    return varied_value

# %%
for _ in range(20):
    print(sample_super_sub_position())
# Out:
# add_varies:  0.0
# 0.85
# add_varies:  0.01
# 0.76
# add_varies:  -0.02
# 0.64
# add_varies:  0.04
# 0.7000000000000001
# add_varies:  -0.01
# 0.65
# add_varies:  -0.03
# 0.72
# add_varies:  0.02
# 0.68
# add_varies:  0.03
# 0.78
# add_varies:  0.03
# 0.6900000000000001
# add_varies:  -0.04
# 0.71
# add_varies:  0.01
# 0.76
# add_varies:  0.0
# 0.75
# add_varies:  0.03
# 0.78
# add_varies:  -0.05
# 0.61
# add_varies:  0.05
# 0.55
# add_varies:  -0.02
# 0.73
# add_varies:  0.04
# 0.7000000000000001
# add_varies:  0.05
# 0.7100000000000001
# add_varies:  -0.03
# 0.47
# add_varies:  0.03
# 0.6900000000000001

# %%
plot_distribution(sample_super_sub_position_v1, "super_sub_position", num_samples=1000)

# %% [markdown]
# Add sample function for superscript and subscript / main_text ratio

# %%
def sample_super_sub_main_text_ratio_v1():
    fixed_ratios = [0.25, 0.3, 0.38, 0.55, 0.7]
    fixed_ratios = list(range(len(fixed_ratios)))
    n = len(fixed_ratios)
    
    add_varies = random.randint(-8, 10) / 100
    
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=3,  # peak at 'a'
        std=7,
        tail_smooth='both',
        baseline_weight=0.3,
        suppression_strength=0,
        size=1
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    varied_value = fixed_ratios[idx] + add_varies
    if varied_value > 1:
        varied_value = 1
    return fixed_ratios[idx]

def sample_super_sub_main_text_ratio():
    fixed_ratios = [0.35, 0.4, 0.48, 0.65, 0.75]
    n = len(fixed_ratios)
    
    add_varies = random.randint(-8, 10) / 100
    print("add_varies: ", add_varies)
    samples = sample_truncnorm_with_tail_and_baseline(
        min_val=0,
        max_val=n - 1,
        mean=3,  # peak at 'a'
        std=7,
        tail_smooth='both',
        baseline_weight=0.3,
        suppression_strength=0,
        size=1
    )
    idx = int(round(samples[0].clip(0, n - 1)))
    varied_value = fixed_ratios[idx] + add_varies
    if varied_value > 1:
        varied_value = 1
    return varied_value

# %%
plot_distribution(sample_super_sub_main_text_ratio_v1, "super_sub_main_text_ratio", num_samples=1000)

# %%
for _ in range(20):
    print(sample_super_sub_main_text_ratio())
# Out:
# add_varies:  -0.03
# 0.62
# add_varies:  0.0
# 0.48
# add_varies:  0.01
# 0.49
# add_varies:  0.06
# 0.81
# add_varies:  -0.06
# 0.42
# add_varies:  0.06
# 0.71
# add_varies:  0.0
# 0.4
# add_varies:  0.05
# 0.53
# add_varies:  0.02
# 0.67
# add_varies:  0.0
# 0.48
# add_varies:  -0.03
# 0.62
# add_varies:  -0.06
# 0.42
# add_varies:  0.0
# 0.35
# add_varies:  -0.07
# 0.41
# add_varies:  0.04
# 0.52
# add_varies:  0.04
# 0.6900000000000001
# add_varies:  0.02
# 0.42000000000000004
# add_varies:  -0.07
# 0.6799999999999999
# add_varies:  0.0
# 0.75
# add_varies:  0.0
# 0.4

# %% [markdown]
# Define the function for select the value based on the ratio

# %%
def sample_by_ratio(numbs, ratio):
    pass


def sample_by_precentage(percentage_True):
    # return percentage that is true
    # 10 percentage that is True
    threshold = 100 - percentage_True
    if np.random.randint(1, 100 + 1) > threshold:
        return True
    else:
        return False

# %% [markdown]
# function to genrate superscript and sunscript with main text

# %%
import random
import math

def generate_text_combinations_by_percentage(main_words_file, get_superscripts, get_subscripts, superscript_percentage):
    with open(main_words_file, 'r', encoding='utf-8') as f:
        main_words = sorted([line.strip() for line in f if line.strip()])

    total_words = len(main_words)
    if total_words == 0:
        raise ValueError("No valid main words found in the file.")

    n_superscripts = math.floor(total_words * superscript_percentage)
    n_subscripts = total_words - n_superscripts

    # Randomize main words to mix assignment
    random.shuffle(main_words)
    supers_words = main_words[:n_superscripts]
    subs_words = main_words[n_superscripts:]

    # Get modifier lists
    superscripts = get_superscripts(n_superscripts)
    subscripts = get_subscripts(n_subscripts)

    result = []
    result2 = []

    for word, sup in zip(supers_words, superscripts):
        result.append(f"{word}~{sup}")
        result2.append((word,sup,"super"))

    for word, sub in zip(subs_words, subscripts):
        result.append(f"{word}_{sub}")
        result2.append((word,sub,"sub"))
 
    return result , result2


######################## add for both super and subscript
import random
import math

def generate_whole_text_by_percentage(main_words_file, get_superscripts, get_subscripts, super_percentage, sub_percentage):
    with open(main_words_file, 'r', encoding='utf-8') as f:
        main_words = sorted([line.strip() for line in f if line.strip()])

    total_words = len(main_words)
    if total_words == 0:
        raise ValueError("No valid main words found in the file.")

    n_superscripts = math.floor(total_words * super_percentage)
    n_subscripts = math.floor(total_words * sub_percentage)
    n_super_subscripts = total_words - n_superscripts - n_subscripts

    # Randomize main words to mix assignment
    random.shuffle(main_words)
    supers_words = main_words[:n_superscripts]
    subs_words = main_words[n_superscripts:n_superscripts + n_subscripts]
    supers_subs_words = main_words[n_superscripts + n_subscripts:]

    # Get modifier lists
    superscripts = get_superscripts(n_superscripts)
    subscripts = get_subscripts(n_subscripts)
    both_superscripts, both_subscripts = get_superscripts(n_super_subscripts), get_subscripts(n_super_subscripts)

    result = []
    result2 = []

    for word, sup in zip(supers_words, superscripts):
        result.append(f"{word}~{sup}")
        result2.append((word,sup,"super"))

    for word, sub in zip(subs_words, subscripts):
        result.append(f"{word}_{sub}")
        result2.append((word,sub,"sub"))

    for word, sup, sub in zip(supers_subs_words, both_superscripts, both_subscripts):
        result.append(f"{word}_{sub}~{sup}")
        result2.append((word, sub, sup, "subsuper"))
    return result , result2

# %% [markdown]
# Add changes to Tairen latest code

# %%
def run_generation_final(
    main_words_file,
    num_of_img_per_font=20,
    output_folder="./outputs2/output_1",
    output_label="./outputs2/",
    font_folder="./fonts",
    background_folder="./img",
    superscript_percentage = 0.85,
    subscript_percentage = 0.1
):
    os.makedirs(output_folder, exist_ok=True)
    
    fonts = [f for f in os.listdir(font_folder) if f.endswith('.ttf')]
    
    if os.path.isdir(background_folder):
        backgrounds = [f for f in os.listdir(background_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
    else:
        print(" The text background color should be mentioned")
        sys.exit()
    
    _, gen_whole_words = generate_whole_text_by_percentage(main_words_file, 
                                                           generate_superscripts_fixed, 
                                                           generate_subscript_fixed, 
                                                           superscript_percentage, 
                                                           subscript_percentage)

    save_annotations_file = os.path.join(output_label, "label.txt")
    
    for font_file in fonts:
        num_img_per_font_count = 0
        font_path = os.path.join(font_folder, font_file)
        
        # to avoid repeating the generated words
        random.shuffle(gen_whole_words)
        
        for gen_word in gen_whole_words:
            gen_type = gen_word[-1]
            # loop over texts
            if gen_type == "super":
                main_text, sup_script = gen_word[:2]
                sub_script = None
                add_text = f"{main_text}`{sup_script}"
            elif gen_type == "sub":
                main_text, sub_script = gen_word[:2]
                sup_script = None
                add_text = f"{main_text}_{sub_script}"
            else:
                main_text, sub_script, sup_script = gen_word[:3]
                add_text = f"{main_text}_{sub_script}`{sup_script}"
            
            gen_font_size = sample_font_size()
            
            pad_all=[np.random.randint(0, 4), np.random.randint(0, 4), np.random.randint(0, 4), np.random.randint(0, 4)]
            
            percentage_use_bkground = 10
            use_image_bg = sample_by_precentage(percentage_use_bkground) # whether to use background images or not
        
            num_img_per_font_count += 1
            
            font_color_category, generated_text_color = sample_font_color()
            
            super_sub_position = sample_super_sub_position()
            
            super_sub_size_ratio = sample_super_sub_main_text_ratio()
            
            if use_image_bg:
                bg_file = random.choice(backgrounds)
                current_bg_path = os.path.join(background_folder, bg_file)
                bg_name = "bg_img_" + os.path.splitext(bg_file)[0]
                gen_bg_color_arg = None
                text_color_for_overlay = generated_text_color
                text_color_for_generate = generated_text_color
            else:
                backg_color_category, background_color = sample_background_color()
                
                adjusted_text_color, adjusted_bg_color, new_ctr = ensure_readable_colors(
                    generated_text_color, background_color)

                current_bg_path = None
                gen_bg_color_arg = adjusted_bg_color
                text_color_for_overlay = adjusted_text_color
                text_color_for_generate = adjusted_text_color
                bg_name = f"solid_{backg_color_category}"
                
            name_base = f"{bg_name}_{os.path.splitext(font_file)[0]}"
            text_color_normalized = normalize_rgba(text_color_for_generate)
            
            # for synthetic image generating
            text_size, gen_image, super_or_sub = generate_text_image(
                main_text=main_text,
                super_text=sup_script,
                sub_text=sub_script,
                text_color=text_color_normalized,
                super_sub_position=super_sub_position,
                super_sub_size=gen_font_size * super_sub_size_ratio,
                font_size=gen_font_size,
                font_type=font_path,
            )
            
            if super_or_sub == 0:
                type = "super"
            elif super_or_sub == 1:
                type = "sub"
            else:
                type = "supersub"
            
            
            # remove the "\" in "\{" and "\}"
            if sup_script is not None:
                if "{" in sup_script or "}" in sup_script:
                    upd_supscript = sup_script.replace("\{", "{").replace("\}", "}")
                else:
                    upd_supscript = sup_script
            else:
                upd_supscript = sup_script
            
            if sub_script is not None:
                if "{" in sub_script or "}" in sub_script:
                    upd_subscript = sub_script.replace("\{", "{").replace("\}", "}")
                else:
                    upd_subscript = sub_script
            else:
                upd_subscript = sub_script
            
            save_image_name = f"{name_base}_{gen_font_size}sz_{type}_{main_text}_{upd_supscript}_{upd_subscript}.png"
            
            # save to image folder
            add_image_folder = os.path.join(output_folder, 'image')
            os.makedirs(add_image_folder, exist_ok=True)
            
            final_sup_path = os.path.join(add_image_folder, save_image_name)

            if "{" in add_text or "}" in add_text:
                add_text = add_text.replace("\{", "{").replace("\}", "}")

            with open(save_annotations_file, "a") as wfile:
                wfile.write("\t".join([final_sup_path, add_text]) + "\n")
            
            overlay_on_background(
                gen_image,
                final_sup_path,
                text_color_for_overlay,
                current_bg_path,
                gen_bg_color_arg,
                pad_all=pad_all
            )
            
            if num_img_per_font_count == num_of_img_per_font:
                break

# %%
main_words_file  = "./data_1/train_1_TR/train_main_text.txt"
run_generation_final(    
    main_words_file,
    num_of_img_per_font=80,
    output_folder="./outputs_TR/test_final/",
    output_label="./outputs_TR/test_final/",
    font_folder="../fonts",
    background_folder="../img_dir")
# Out:
# [INFO] Generating 8801 superscripts:
#   Digits:   2640
#   Lower:    1760
#   Upper:    441
#   Brackets: 3960
#
# [INFO] Bracket styles:
#   → ():     3168
#   → []:     396
#   → {}:    396
#
# [INFO] Bracket inner content distribution:
#   → Digit-only:    1980
#   → Lower-only:    1782
#   → Upper-only:    198
# [INFO] Final Distribution Summary:
# Digits:     2640
# Lower:      1760
# Upper:      441
# Brackets:   3960
#   → ():     3168
#   → []:     396
#   → {}:     396
# [INFO] Generating 1035 superscripts:
#   Digits:   518
#   Lower:    310
#   Upper:    207
#
# [INFO] Final Distribution Summary:
# Digits:     518
# Lower:      310
# Upper:      207
# [INFO] Generating 519 superscripts:
#   Digits:   156
#   Lower:    104
#   Upper:    25
#   Brackets: 234
#
# [INFO] Bracket styles:
#   → ():     187
#   → []:     23
#   → {}:    24
#
# [INFO] Bracket inner content distribution:
#   → Digit-only:    117
#   → Lower-only:    105
#   → Upper-only:    12
#
# [INFO] Final Distribution Summary:
# Digits:     156
# Lower:      104
# Upper:      25
# Brackets:   234
#   → ():     187
#   → []:     23
#   → {}:     24
# [INFO] Generating 519 superscripts:
#   Digits:   260
#   Lower:    156
#   Upper:    103
#
# [INFO] Final Distribution Summary:
# Digits:     260
# Lower:      156
# Upper:      103
# add_varies:  -0.02
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_sub_11,000_None_7.png
# add_varies:  -0.03
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_13sz_supersub_PATIENT_(a,f)_A,I.png
# add_varies:  0.03
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_3sz_super_PLAT,_(a,b)_None.png
# add_varies:  0.01
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_socialsecurity._1,2,3_None.png
# add_varies:  0.02
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_supersub_CREDITS_a_a,w.png
# add_varies:  0.01
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_60_NotoSans-Regular_17sz_super_'Reasoinable_A_None.png
# add_varies:  0.0
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_61_NotoSans-Regular_15sz_super_plugs_{7}_None.png
# add_varies:  -0.02
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_17sz_super_NIUM_(k)_None.png
# add_varies:  -0.04
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_8sz_super_Hayward_Y_None.png
# add_varies:  -0.04
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_78,107_{2}_None.png
# add_varies:  0.03
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_8sz_super_Washington._(v)_None.png
# add_varies:  -0.03
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_9sz_super_Premium:_(a)_None.png
# add_varies:  -0.04
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_8sz_super_completelyde_(2)_None.png
# add_varies:  -0.04
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_NotoSans-Regular_6sz_super_$442,487,230)_[b,w]_None.png
# add_varies:  0.01
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_NotoSans-Regular_13sz_super_$5,194,_1,4_None.png
# add_varies:  0.03
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_8sz_super_repayment._1,6,7_None.png
# add_varies:  -0.02
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_185,754,033_4_None.png
# add_varies:  0.0
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_4sz_super_service_[P,W]_None.png
# add_varies:  0.03
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_9_NotoSans-Regular_7sz_super_retained_2_None.png
# add_varies:  0.05
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_5sz_sub_(11,795_None_c.png
# add_varies:  -0.02
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_UMMY_(r)_None.png
# add_varies:  -0.03
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_14sz_super_SignalAve_8_None.png
# add_varies:  0.05
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_8889_(l)_None.png
# add_varies:  0.03
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_8sz_super_(3,479)_[8]_None.png
# add_varies:  0.04
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_9sz_super_9700947-9000_1_None.png
# add_varies:  0.05
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_Issuanc_{a,g}_None.png
# add_varies:  -0.01
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_29,459,460_(1)_None.png
# add_varies:  -0.05
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_5sz_super_"doing_(1,2,7)_None.png
# add_varies:  -0.03
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_135,915.51_1,6_None.png
# add_varies:  0.02
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_feewillbe_(a,b,l,q,t)_None.png
# add_varies:  -0.04
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_Standards:_(2)_None.png
# add_varies:  -0.03
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_12sz_super_valuables_(1,3)_None.png
# add_varies:  0.0
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_$8,411_(1,2,3,4,5,6)_None.png
# add_varies:  0.0
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_sewerret_(a,c,n,v)_None.png
# add_varies:  0.01
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_6sz_super_lease._(1,2,3)_None.png
# add_varies:  0.0
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_5sz_super_ccccccccccccccc_(u)_None.png
# add_varies:  0.02
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_Barb_b_None.png
# add_varies:  -0.01
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_10sz_super_Releases._(1,2,3,6,9)_None.png
# add_varies:  -0.03
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_8sz_super_180_b,i,j,y_None.png
# add_varies:  -0.04
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_8sz_supersub_(216,155)_{1}_C,M.png
# add_varies:  0.0
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_029707-01-2044_b,y_None.png
# add_varies:  -0.04
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_holderonlyonthe_(a,b,c,f,t)_None.png
# add_varies:  0.0
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_6sz_super_shake_(9)_None.png
# add_varies:  0.05
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_MILANO_[7,8]_None.png
# add_varies:  -0.03
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_6sz_supersub_Aggregate_1_a,b.png
# add_varies:  -0.05
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_mortga_(d,x)_None.png
# add_varies:  0.05
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_16sz_sub_qualification_None_I.png
# add_varies:  0.01
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_6sz_sub_IVFloor_None_2.png
# add_varies:  0.05
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_5sz_super_(4,168,840)_a,d_None.png
# add_varies:  0.01
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_20sz_super_(14,509)_1,2,4_None.png
# add_varies:  -0.04
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_8sz_super_(29,966)_9_None.png
# add_varies:  0.0
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_sub_MICROPRINTING_None_1,6,8.png
# add_varies:  -0.01
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_10sz_super_08-01-2024_1,2,5,6_None.png
# add_varies:  -0.02
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_8sz_super_324.93_(a)_None.png
# add_varies:  -0.03
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_0_NotoSans-Regular_5sz_super_withholdingtaxon_{1,3}_None.png
# add_varies:  -0.05
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_THEEXECT_(2)_None.png
# add_varies:  0.05
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_6sz_super_dropped_[5]_None.png
# add_varies:  0.02
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_MOLD:_1_None.png
# add_varies:  0.0
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_4sz_super_N.A.,_b,g_None.png
# add_varies:  0.03
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_6sz_super_atClosing_a,x_None.png
# add_varies:  0.03
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_35,254.72_(1,2,3,4,6)_None.png
# add_varies:  0.0
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_325,141.48_{7}_None.png
# add_varies:  -0.02
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_NotoSans-Regular_8sz_super_1,642,128_3_None.png
# add_varies:  -0.04
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_369.41_(a,d,i,v)_None.png
# add_varies:  0.05
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_NotoSans-Regular_12sz_super_"Environmental_r_None.png
# add_varies:  -0.03
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_6sz_super_government_(3,4)_None.png
# add_varies:  -0.01
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_14sz_sub_FLMod_None_b.png
# add_varies:  -0.02
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_6sz_sub_FLStateWages,_None_1,2,3,6.png
# add_varies:  0.04
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_5sz_super_benefits_B_None.png
# add_varies:  -0.04
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_4sz_super_$36,378,259_a,u,w_None.png
# add_varies:  0.04
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_NotoSans-Regular_5sz_super_Increase_2_None.png
# add_varies:  0.02
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_sub_opening_None_1.png
# add_varies:  0.01
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_11sz_super_liability;_{1}_None.png
# add_varies:  0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_8sz_supersub_16511350_7_1,2,8.png
# add_varies:  0.0
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_19sz_super_592,858_(a,b,d,w,x)_None.png
# add_varies:  -0.01
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_.cfm_(A,B,D,G,O,U)_None.png
# add_varies:  0.01
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_7sz_super_Right_1,3_None.png
# add_varies:  -0.05
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_NotoSans-Regular_6sz_super_prepare_3,4,7_None.png
# add_varies:  0.04
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_15570.00_[1,2,3,4]_None.png
# add_varies:  0.03
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_NotoSans-Regular_7sz_super_1,622.39_1,8_None.png
# add_varies:  -0.03
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_13sz_supersub_www.energystar_{3}_1,2,3,5,9.png
# add_varies:  -0.02
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_8sz_super_share_(1,2,4,6,7,8)_None.png
# add_varies:  -0.01
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_8sz_super_od.Foremoreinfor_1_None.png
# add_varies:  0.0
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_times_new_roman_7sz_super_ceproceedsin_1_None.png
# add_varies:  -0.05
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_6sz_super_describedinand_(c,i,o,x)_None.png
# add_varies:  0.05
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_19sz_super_$2,800.00_j,m,q_None.png
# add_varies:  -0.04
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_4_times_new_roman_3sz_supersub_es_1,2_3.png
# add_varies:  -0.01
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_end_(1,2,6,7)_None.png
# add_varies:  -0.02
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_37_times_new_roman_10sz_super_"Your_1,2,6_None.png
# add_varies:  0.02
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_5sz_super_8863_b,m_None.png
# add_varies:  0.0
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_1472100_(o)_None.png
# add_varies:  -0.01
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_11sz_super_llen_(1,2,6,7)_None.png
# add_varies:  0.0
# add_varies:  0.08
# Error overlaying images: object of type 'numpy.float64' has no len()
# add_varies:  0.05
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_3sz_super_98)%_{a,t}_None.png
# add_varies:  0.0
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_5sz_super_impairment_(7,8)_None.png
# add_varies:  -0.04
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_diluted_(a,l)_None.png
# add_varies:  0.0
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_sub_guardian_None_B.png
# add_varies:  -0.04
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_19sz_super_4.295%_2,3,5_None.png
# add_varies:  0.0
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_14sz_super_Thursday,_1,4_None.png
# add_varies:  -0.03
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_57_times_new_roman_7sz_super_212.73_a,b,d,n,t,x_None.png
# add_varies:  -0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_20sz_super_refun_(a,l,p,s,t)_None.png
# add_varies:  -0.02
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_yet_(1,2,5,9)_None.png
# add_varies:  -0.03
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_System,_(7)_None.png
# add_varies:  -0.04
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_7sz_super_$151,958.87_2,5_None.png
# add_varies:  0.02
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_5sz_sub_cates._None_1,2,7.png
# add_varies:  0.04
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_7sz_super_constifute_a,b,v_None.png
# add_varies:  -0.05
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_2sz_super_plain_1,2_None.png
# add_varies:  -0.05
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_2243{_k,m_None.png
# add_varies:  -0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_times_new_roman_16sz_super_ttomortgage._a,b_None.png
# add_varies:  0.01
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_4sz_super_Sagewood,_h,u_None.png
# add_varies:  0.0
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_3sz_super_9994944-5801_o_None.png
# add_varies:  0.02
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_16sz_super_driveways,_(1,2,3)_None.png
# add_varies:  -0.03
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_supersub_concessions_4_1.png
# add_varies:  -0.03
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_7sz_super_Ib_(1,2,6,8)_None.png
# add_varies:  0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_HALLI_a,b_None.png
# add_varies:  0.0
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_0.68_(a)_None.png
# add_varies:  -0.04
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_6sz_super_PuneBranch_1,2,5_None.png
# add_varies:  0.02
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_39_times_new_roman_7sz_sub_F.P.O_None_e,v,z.png
# add_varies:  -0.01
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_15sz_super_$452.12_4,8_None.png
# add_varies:  0.01
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_430.17_(4)_None.png
# add_varies:  -0.05
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_times_new_roman_8sz_super_instr._(a,c,q)_None.png
# add_varies:  -0.03
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_times_new_roman_9sz_super_1)098055649_1_None.png
# add_varies:  -0.04
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_19_times_new_roman_5sz_super_thereafter_(o)_None.png
# add_varies:  0.05
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_times_new_roman_6sz_super_card._[b]_None.png
# add_varies:  -0.01
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_20sz_super_Identified._2,4_None.png
# add_varies:  -0.04
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_7sz_super_financial,_2,8_None.png
# add_varies:  -0.01
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_16sz_super_386-212-7333_g,s_None.png
# add_varies:  -0.05
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_9sz_super_ToGivetheRequest_{3,7}_None.png
# add_varies:  0.0
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_36_times_new_roman_7sz_super_$(273,616.78)_(b,k,p,u,z)_None.png
# add_varies:  0.02
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_10sz_supersub_(17.06.16)_q_1,4.png
# add_varies:  -0.05
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_5sz_super_Chetty_1,9_None.png
# add_varies:  0.03
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_69_times_new_roman_5sz_super_950117_2,6_None.png
# add_varies:  0.04
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_11sz_super_9970574-9509_c,n_None.png
# add_varies:  -0.01
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_7sz_super_-13_j_None.png
# add_varies:  0.04
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_(424,196)_(1)_None.png
# add_varies:  0.04
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_4sz_super_preferred_1,2,6,8_None.png
# add_varies:  0.03
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_NUMBER._(y)_None.png
# add_varies:  -0.02
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_6_times_new_roman_4sz_super_3,665_(b,i)_None.png
# add_varies:  0.03
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_Theunde_a,b,h,s_None.png
# add_varies:  0.0
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_17sz_supersub_wapinc._b_2.png
# add_varies:  -0.03
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_8sz_super_CONSUMER'S_(a,j,l,t)_None.png
# add_varies:  0.0
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_14sz_super_(492,604)_(2,5,6)_None.png
# add_varies:  0.01
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_14sz_super_CHATE_1_None.png
# add_varies:  -0.01
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_5sz_super_IRVING,_(3)_None.png
# add_varies:  0.03
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_times_new_roman_6sz_super_r,"_(a,h)_None.png
# add_varies:  -0.04
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_8sz_super_consulting_1,2,7_None.png
# add_varies:  0.05
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_approv_(2,3)_None.png
# add_varies:  -0.01
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_7sz_super_Towne_7_None.png
# add_varies:  -0.05
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_D.O.BIRTH_(3,7)_None.png
# add_varies:  -0.05
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_VEHICLE_(1)_None.png
# add_varies:  -0.02
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_9967560-5801_b_None.png
# add_varies:  -0.05
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_6sz_super_Federalstatutes_(z)_None.png
# add_varies:  -0.04
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_8sz_super_9164313968862908_4,6,8_None.png
# add_varies:  -0.05
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_3sz_super_stee_1,2,7_None.png
# add_varies:  -0.03
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_4sz_super_IFSC_3_None.png
# add_varies:  0.04
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_7sz_super_9709529490_(1,2,3,5)_None.png
# add_varies:  -0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_times_new_roman_13sz_supersub_24,250,110_2_A,W.png
# add_varies:  0.04
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_times_new_roman_6sz_super_Deb_1,2,3,5,6_None.png
# add_varies:  -0.04
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_11_times_new_roman_16sz_super_SEND_(1,5)_None.png
# add_varies:  0.01
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_times_new_roman_7sz_super_652-066-630-767_a,e,o,z_None.png
# add_varies:  -0.04
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_6sz_supersub_y.org_a_1,2,3,8.png
# add_varies:  0.01
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_17sz_super_od_1,2_None.png
# add_varies:  0.03
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_10sz_super_activity_[q]_None.png
# add_varies:  -0.02
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_super_Cambodian,_b_None.png
# add_varies:  0.05
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_6sz_sub_DEVIATION._None_8.png
# add_varies:  -0.01
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_sub_investments_None_1,2,4.png
# add_varies:  0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_16sz_super_F'_1_None.png
# add_varies:  -0.01
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_3sz_super_Taxable_(a,b)_None.png
# add_varies:  -0.05
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_41_Garamond_Regular_6sz_super_(3.9)_[b,k]_None.png
# add_varies:  -0.03
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_11sz_super_Sharjah_1,2,4,5,8_None.png
# add_varies:  -0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_7sz_sub_366,991.39_None_b,w.png
# add_varies:  0.0
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_5sz_super_Anytown,_(h)_None.png
# add_varies:  0.01
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_10_Garamond_Regular_6sz_super_eling._(8)_None.png
# add_varies:  -0.05
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_11sz_super_Riders"_3_None.png
# add_varies:  -0.04
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_Garamond_Regular_5sz_super_"As_3,6_None.png
# add_varies:  -0.04
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Garamond_Regular_6sz_super_($71,079)_(a,b)_None.png
# add_varies:  0.04
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_5sz_super_INFO!!_1_None.png
# add_varies:  0.04
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_11sz_super_owned,_2_None.png
# add_varies:  -0.01
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_6sz_super_1,31,879_(2,3)_None.png
# add_varies:  -0.03
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_4sz_sub_366,796_None_A,T.png
# add_varies:  -0.04
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_39_Garamond_Regular_6sz_super_23,267_(b,d,e,h,l)_None.png
# add_varies:  0.01
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_12sz_super_55904-7134_a,b_None.png
# add_varies:  -0.03
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_7sz_super_Premiums_b,j,t_None.png
# add_varies:  0.03
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_3sz_sub_PERTS_None_5.png
# add_varies:  -0.02
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_9sz_super_kin_(8)_None.png
# add_varies:  0.03
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_5sz_super_ccccccccccccccc_(u)_None.png
# add_varies:  0.01
# add_varies:  -0.04
# background does not have enough contrast with text
# Generate the background instead
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_51_Garamond_Regular_10sz_super_Chi_(n)_None.png
# add_varies:  -0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_9sz_sub_gmail.c_None_e.png
# add_varies:  -0.02
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_26_Garamond_Regular_8sz_super_od.Foremoreinfor_1_None.png
# add_varies:  -0.01
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_6sz_super_Refrigerator_2_None.png
# add_varies:  0.02
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_Garamond_Regular_8sz_super_court._(1,2,4)_None.png
# add_varies:  0.02
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_10sz_super_9708580635_[5]_None.png
# add_varies:  -0.03
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Garamond_Regular_5sz_super_costs:_(6,7)_None.png
# add_varies:  0.05
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_5sz_super_hands,_(1,6)_None.png
# add_varies:  0.01
# add_varies:  -0.01
# background does not have enough contrast with text
# Generate the background instead
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_26_Garamond_Regular_11sz_super_GANESHNA_(b)_None.png
# add_varies:  0.04
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_super_YEARS_2_None.png
# add_varies:  0.01
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_5sz_super_Disposable_2,3_None.png
# add_varies:  -0.01
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_8sz_super_18,558,455_b,e,w_None.png
# add_varies:  -0.02
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_9sz_super_ditionsofthes_{1,2,4,6,7,8}_None.png
# add_varies:  0.03
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Garamond_Regular_7sz_super_iod,_[1]_None.png
# add_varies:  0.03
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_super_$350,0002019_8_None.png
# add_varies:  0.0
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Garamond_Regular_8sz_super_Amount:_(a,f)_None.png
# add_varies:  0.01
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_4sz_super_deteriorate_1,2,5_None.png
# add_varies:  -0.03
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_6sz_super_OH._J_None.png
# add_varies:  -0.05
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_14sz_super_Guard_1,2,5_None.png
# add_varies:  -0.05
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_9sz_super_106736.14_1,2_None.png
# add_varies:  0.01
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_15sz_supersub_rnal_1,2,8_a,t.png
# add_varies:  0.05
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_super_891,117_1,5_None.png
# add_varies:  0.02
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_8sz_super_valances,_a_None.png
# add_varies:  0.02
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_13sz_sub_SocialSecurity_None_a,b,n,x.png
# add_varies:  -0.05
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_4sz_super_AIM_1_None.png
# add_varies:  0.0
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_8sz_super_uIlders.com_2,6_None.png
# add_varies:  0.0
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_6sz_super_0.73_1,2_None.png
# add_varies:  -0.01
# add_varies:  -0.07
# background does not have enough contrast with text
# Generate the background instead
# Error overlaying images: 'numpy.float64' object cannot be interpreted as an integer
# add_varies:  0.05
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_14sz_super_Iieu_a,z_None.png
# add_varies:  -0.05
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_5sz_super_earmarked_B,K,P,S,Z_None.png
# add_varies:  -0.01
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_9sz_super_rabusinessadd_1,2,3,7,8_None.png
# add_varies:  0.02
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_11sz_super_ESA,_c_None.png
# add_varies:  0.0
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_20sz_super_2185_a,e_None.png
# add_varies:  -0.02
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_16sz_super_Stephen_P_None.png
# add_varies:  -0.04
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Garamond_Regular_7sz_super_(443,490)_(B)_None.png
# add_varies:  -0.02
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_14sz_super_DURING_(b)_None.png
# add_varies:  -0.01
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_6sz_super_CRN_(c,t)_None.png
# add_varies:  0.02
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_11sz_super_COLLEEN_(1)_None.png
# add_varies:  0.0
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_7sz_super_IN.EY._[b,f]_None.png
# add_varies:  -0.01
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_17sz_super_0:44_(a,b,j,p,r,v)_None.png
# add_varies:  -0.05
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Garamond_Regular_3sz_super_provider_f_None.png
# add_varies:  -0.04
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_super_Recruitment_b,f,n_None.png
# add_varies:  0.04
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Garamond_Regular_8sz_super_grant_(a)_None.png
# add_varies:  -0.04
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_super_LETTER,_(4)_None.png
# add_varies:  -0.04
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_66_Garamond_Regular_7sz_super_?Financial,_a_None.png
# add_varies:  -0.03
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_8sz_super_TALE_{1,2,5}_None.png
# add_varies:  -0.05
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_7sz_sub_Kansas,_None_1,2.png
# add_varies:  0.04
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_Garamond_Regular_7sz_super_9980389-90006_B,Y_None.png
# add_varies:  0.0
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_6sz_sub_Building_None_1,2,6,7,9.png
# add_varies:  0.0
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_6sz_super_cumbrances_4_None.png
# add_varies:  -0.02
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_Garamond_Regular_18sz_super_(359,965)_B,T,Y_None.png
# add_varies:  -0.05
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Garamond_Regular_11sz_super_laimslimitedt_(1)_None.png
# add_varies:  0.05
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Garamond_Regular_4sz_super_Months._w_None.png
# add_varies:  -0.01
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Garamond_Regular_15sz_super_valuables_(1,3)_None.png
# add_varies:  -0.04
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_5sz_super_$18.89_j,r_None.png
# add_varies:  0.0
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_18sz_super_32,594,491_1,2,3,5,8_None.png
# add_varies:  -0.03
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_7sz_super_tle_2,3_None.png
# add_varies:  -0.01
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Merriweather-Regular_8sz_super_oflssue_1,3_None.png
# add_varies:  0.04
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_5sz_super_artists,_q_None.png
# add_varies:  -0.05
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_7sz_super_5391667928_p,s_None.png
# add_varies:  -0.03
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_8sz_super_7:33_[a]_None.png
# add_varies:  0.04
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_8sz_super_583,352_1,3_None.png
# add_varies:  0.02
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_9sz_sub_Ronnie_None_A,F,P,S,U.png
# add_varies:  0.03
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Merriweather-Regular_19sz_super_complies_1_None.png
# add_varies:  -0.04
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_8sz_super_creditscan_(1,3,6)_None.png
# add_varies:  -0.03
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_Merriweather-Regular_8sz_super_03-01-2026_1,9_None.png
# add_varies:  -0.03
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_4sz_super_,03,390.42_(1,2)_None.png
# add_varies:  0.01
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Merriweather-Regular_6sz_super_tructed_A_None.png
# add_varies:  -0.03
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_12sz_super_gave_c_None.png
# add_varies:  -0.04
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_54_Merriweather-Regular_7sz_sub_(-$228.94)_None_2.png
# add_varies:  -0.03
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_10sz_supersub_(7,565)_(1)_q.png
# add_varies:  0.01
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_7sz_super_069.37_2_None.png
# add_varies:  -0.04
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_5sz_super_thevalueof_(a,o)_None.png
# add_varies:  0.04
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_4sz_super_imile_(W)_None.png
# add_varies:  -0.05
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_8sz_super_current_(1,8)_None.png
# add_varies:  -0.05
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_6sz_super_outside_a,b,c_None.png
# add_varies:  0.02
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_6sz_super_iums_(1,6)_None.png
# add_varies:  0.02
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_9sz_supersub_IU_(4)_1,4.png
# add_varies:  0.01
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_34_Merriweather-Regular_8sz_super_(49,698)_[8]_None.png
# add_varies:  0.0
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_8sz_super_100.12_H_None.png
# add_varies:  0.05
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Merriweather-Regular_7sz_sub_instrumentalit_None_1,2,3,5,8,9.png
# add_varies:  0.0
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_35_Merriweather-Regular_5sz_super_Docket_3,6_None.png
# add_varies:  -0.03
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_7sz_super_817-924-5091_1,7_None.png
# add_varies:  0.05
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_11sz_super_grates_b,o_None.png
# add_varies:  -0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_10sz_supersub_(800)569-4287_1,2,3,5,7,8_1,2,3,4,8.png
# add_varies:  -0.01
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_7sz_super_DIRECTORS_(1,5)_None.png
# add_varies:  0.02
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_20_Merriweather-Regular_6sz_super_119._2_None.png
# add_varies:  0.01
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_6sz_super_EXTILE_c,r_None.png
# add_varies:  0.01
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_6sz_super_licensees_1,6_None.png
# add_varies:  0.05
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_7sz_sub_Upon_None_5.png
# add_varies:  0.04
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_6sz_super_proponent_(t)_None.png
# add_varies:  -0.02
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_6sz_super_ALTERNATE_(1)_None.png
# add_varies:  0.02
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_Merriweather-Regular_14sz_sub_ref._None_1,2,3,4,8,9.png
# add_varies:  -0.04
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Merriweather-Regular_5sz_super_4420_1_None.png
# add_varies:  -0.03
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_13sz_super_8)._(a,g,s)_None.png
# add_varies:  -0.02
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_4sz_super_'Property_1,2_None.png
# add_varies:  0.04
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_7sz_supersub_loan_8_m,z.png
# add_varies:  -0.04
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_5sz_super_willing_b_None.png
# add_varies:  0.04
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Merriweather-Regular_7sz_super_MM_2,8_None.png
# add_varies:  0.04
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_7sz_super_5,787,405.70_a,f_None.png
# add_varies:  0.05
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_5sz_super_$9,566_(2)_None.png
# add_varies:  -0.05
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_7sz_super_18,533.31_(1,2,4)_None.png
# add_varies:  0.05
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_15sz_supersub_(4,000)_[a,q,t,y]_1,2.png
# add_varies:  -0.03
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_4sz_super_04-09-2018_(b)_None.png
# add_varies:  0.03
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Merriweather-Regular_5sz_super_152318.51_(1)_None.png
# add_varies:  0.04
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_31_Merriweather-Regular_5sz_super_147246.24_{a}_None.png
# add_varies:  -0.03
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_4sz_super_withregard_n_None.png
# add_varies:  0.05
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_8sz_super_Neutral_{1,2}_None.png
# add_varies:  0.04
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_7sz_super_(474,219)_1,3,6,9_None.png
# add_varies:  -0.02
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Merriweather-Regular_6sz_supersub_93._a,b,c,i_2,9.png
# add_varies:  0.03
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Merriweather-Regular_10sz_super_6,58,427.37_[a,b,d,e,q]_None.png
# add_varies:  0.02
# add_varies:  -0.02
# ...
# add_varies:  -0.03
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_5sz_sub_91900545_None_1.png
# add_varies:  -0.01
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_7sz_super_3,412.00_1,8_None.png
# add_varies:  0.0
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_7sz_super_Fidelity'saudited_g,p_None.png
# add_varies:  0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_Helvetica_2sz_super_borrower'_(1,4)_None.png
# add_varies:  -0.01
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_8sz_super_79,303_B_None.png
# add_varies:  0.03
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_6sz_sub_(449)_None_1,6.png
# add_varies:  0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_6sz_super_Summary_(a,c)_None.png
# add_varies:  -0.01
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_8sz_sub_40754.38_None_1,3.png
# add_varies:  -0.05
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_20sz_super_AUTODRIVER_1,2_None.png
# add_varies:  0.03
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_7sz_super_90,974_1,2,5,7_None.png
# add_varies:  0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_6sz_super_2019)._(1)_None.png
# add_varies:  -0.02
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Helvetica_7sz_super_www.pameganslaw_(3)_None.png
# add_varies:  0.03
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_6sz_sub_14,265,194_None_1,2,3,6.png
# add_varies:  -0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_7sz_super_FULL_b_None.png
# add_varies:  0.05
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_Helvetica_10sz_super_who_(8)_None.png
# add_varies:  0.01
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_7sz_super_drinking_1_None.png
# add_varies:  0.05
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_6sz_super_Hawaii._(f)_None.png
# add_varies:  0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_6sz_super_charges_(a,b,j,l)_None.png
# add_varies:  0.02
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_8sz_super_1-888-549-5690._(b)_None.png
# add_varies:  -0.03
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_Helvetica_15sz_super_copy,_M_None.png
# add_varies:  0.01
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_5sz_super_SIMPLEplans;_a,b,f,r_None.png
# add_varies:  -0.01
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_6sz_super_jobs_1,2,3,6,9_None.png
# add_varies:  -0.03
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_Helvetica_8sz_super_oftheProperty_(1,2,5,7)_None.png
# add_varies:  -0.02
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_3sz_super_taxpayer,_{1,2,4,6,7,8}_None.png
# add_varies:  -0.05
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_44_Helvetica_8sz_sub_Date,_None_1,2,8.png
# add_varies:  0.0
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_7sz_super_(1,813,193)_(d,p)_None.png
# add_varies:  -0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_Helvetica_12sz_super_1,410_4_None.png
# add_varies:  0.04
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_FreeSans_6sz_super_aresubjectto_1,3_None.png
# add_varies:  0.05
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_4sz_super_Additionally,_1,6_None.png
# add_varies:  -0.01
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_20sz_super_liabilities_(a,b,i)_None.png
# add_varies:  0.03
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_10sz_super_BortIett_6_None.png
# add_varies:  -0.02
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_53_FreeSans_13sz_super_outside_a,b,d,g_None.png
# add_varies:  -0.01
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_35_FreeSans_6sz_super_62,280.46_1,5_None.png
# add_varies:  0.02
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_5sz_super_"Highest_(1,2,3)_None.png
# add_varies:  0.04
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_5sz_super_SampleUser_[2]_None.png
# add_varies:  0.05
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_8sz_super_ibition_(4)_None.png
# add_varies:  0.03
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_9sz_sub_1-800-_None_B,N.png
# add_varies:  0.03
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_4sz_super_judgment,_e,z_None.png
# add_varies:  -0.05
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_8sz_super_(210)260-6837_(1,2)_None.png
# add_varies:  -0.04
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_FreeSans_4sz_super_Refunded_[1,2,3,6,9]_None.png
# add_varies:  -0.01
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_9sz_super_(7,957,563)_(n)_None.png
# add_varies:  -0.05
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_22_FreeSans_7sz_super_TAKA_(8,9)_None.png
# add_varies:  -0.04
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_3sz_super_Avg_H_None.png
# add_varies:  -0.02
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_18sz_super_56004_4,8_None.png
# add_varies:  0.04
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_588,924,022_(a,b)_None.png
# add_varies:  0.01
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_apartments_a,m,u_None.png
# add_varies:  -0.02
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_FreeSans_6sz_super_IFSC_3_None.png
# add_varies:  0.01
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_18sz_super_saction_(a,n,r,y)_None.png
# add_varies:  0.03
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_12sz_super_tools_[j,k]_None.png
# add_varies:  0.01
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_super_firm_a,b,c_None.png
# add_varies:  0.05
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_20sz_super_11,127_2,3_None.png
# add_varies:  0.03
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_super_06-01-2043_a,h_None.png
# add_varies:  0.0
# add_varies:  0.05
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_46_FreeSans_18sz_super_$7,715_1,2,3,5,6_None.png
# add_varies:  0.03
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_8sz_super_eportStatemen_(6)_None.png
# add_varies:  -0.02
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_3sz_super_Airoli,_1,7_None.png
# add_varies:  0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_10sz_super_SUVADEEP_2,3,5,6,7_None.png
# add_varies:  0.0
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_6sz_super_Detaills_1,2,3,4,8_None.png
# add_varies:  0.04
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_FreeSans_19sz_super_170.41_f,t_None.png
# add_varies:  0.04
# add_varies:  -0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_12sz_super_ARTICLES,_(4,5)_None.png
# add_varies:  0.04
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_sub_r_None_8.png
# add_varies:  -0.03
# add_varies:  -0.05
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_3sz_super_(3,277,963)_(1,2,3,9)_None.png
# add_varies:  0.02
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_donor_(Y)_None.png
# add_varies:  0.0
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_6sz_super_6,314_a,e_None.png
# add_varies:  -0.05
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_6sz_super_4,986_2_None.png
# add_varies:  0.02
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_5sz_super_atfidelity.com_[1,2,3,5,6,9]_None.png
# add_varies:  -0.03
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_6sz_super_borrower'_(1,4)_None.png
# add_varies:  0.0
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_super_encroachments_(1)_None.png
# add_varies:  -0.01
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_9sz_super_yes,_a,p,r_None.png
# add_varies:  0.03
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_Cash_(2)_None.png
# add_varies:  -0.03
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_6sz_sub_$7,502,240,041)_None_a,b,c,u.png
# add_varies:  0.01
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_super_dry_(4)_None.png
# add_varies:  0.01
# add_varies:  0.09
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_statement_{a,b,c,h,i,m}_None.png
# add_varies:  0.03
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_supersub_,548_c_d,f.png
# add_varies:  0.05
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_9sz_super_inventories._(a,b,c,y)_None.png
# add_varies:  -0.02
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_54,099.00_2,7_None.png
# add_varies:  -0.01
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_FreeSans_6sz_super_10,788_1,2_None.png
# add_varies:  -0.03
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_8sz_super_Gujarat_a,b_None.png
# add_varies:  0.02
# add_varies:  0.02
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_5sz_super_equiredbythe_1,7_None.png
# add_varies:  0.0
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_3sz_super_.47%_{4}_None.png
# add_varies:  -0.02
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_5sz_super_17,558_v_None.png
# add_varies:  -0.03
# add_varies:  0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_super_3,523,173_(1)_None.png
# add_varies:  0.02
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_20sz_super_pharma_(s)_None.png
# add_varies:  -0.02
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_FreeSans_6sz_super_84.13_1,3_None.png
# add_varies:  0.02
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_9sz_super_hts._(1,2)_None.png
# add_varies:  -0.03
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_6sz_super_:42:03_e,u_None.png
# add_varies:  0.03
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_4sz_super_Valuation._a,b,c,h,y_None.png
# add_varies:  -0.03
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_6_FreeSans_6sz_super_apply?_(b)_None.png
# add_varies:  0.01
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_7sz_sub_560-89-6111_None_c.png
# add_varies:  0.01
# add_varies:  0.0
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_5sz_supersub_(31,298,464)_[1,4]_a,b,c,m,w.png
# add_varies:  -0.03
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_FreeSans_7sz_super_REALTOR_(1,6,9)_None.png
# add_varies:  -0.01
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_5sz_super_Group_(l)_None.png
# add_varies:  -0.04
# add_varies:  0.1
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_3sz_sub_ent'_None_1,4.png
# add_varies:  0.01
# add_varies:  -0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_INSD_(d,g)_None.png
# add_varies:  0.0
# add_varies:  -0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_8sz_super_(72,486)_a_None.png
# add_varies:  0.03
# add_varies:  0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_blue_FreeSans_5sz_super_COMMITMENT:_2_None.png
# add_varies:  0.05
# add_varies:  -0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_super_andseverally,_a,d,f,r_None.png
# add_varies:  0.01
# add_varies:  0.07
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_15sz_super_$22.26_a,b_None.png
# add_varies:  -0.02
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_6sz_super_4897_{1,2,3,4,6,9}_None.png
# add_varies:  -0.02
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_9sz_super_nmentonlyduring_(a,b,c,i)_None.png
# add_varies:  -0.03
# add_varies:  0.06
# Combined image saved to ./outputs_TR/test_final/image/solid_light_red_FreeSans_4sz_sub_DISTRICT._None_a,b,i,q,z.png
# add_varies:  -0.01
# add_varies:  -0.02
# Combined image saved to ./outputs_TR/test_final/image/bg_img_background_img_21_FreeSans_9sz_super_454,192,205_(a,d,n,w,x)_None.png
# add_varies:  -0.03
# add_varies:  -0.08
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_7sz_super_OFFERED_(9)_None.png
# add_varies:  -0.01
# add_varies:  -0.03
# Combined image saved to ./outputs_TR/test_final/image/solid_light_yellow_FreeSans_7sz_super_9,972.19_a_None.png
# add_varies:  -0.04
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_11sz_super_121169_1,2,6_None.png
# add_varies:  0.03
# add_varies:  0.01
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_15sz_supersub_SHEET_a,m,n_U,W.png
# add_varies:  0.03
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_white_FreeSans_18sz_super_21,_1_None.png
# add_varies:  0.02
# add_varies:  0.04
# Combined image saved to ./outputs_TR/test_final/image/solid_light_gray_FreeSans_7sz_super_incurorsustai_(1,8,9)_None.png

# %%
! rm -rf ./outputs_TR/train_1/
# Out:
# 4802.03s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
